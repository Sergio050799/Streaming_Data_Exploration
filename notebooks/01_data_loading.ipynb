# %% [markdown]
# # Carga de datos

# %% [markdown]
# ## 0.1 Librerías

# %%
import numpy as np 
import pandas as pd
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.0 Carga de Datos - Plataformas

# %%
Data_Amazon = pd.read_csv('../data/raw/data_amazon_prime_video.csv')
Data_Amazon['platform'] = 'Amazon Prime Video'

Data_Apple = pd.read_csv('../data/raw/data_apple_tv.csv')
Data_Apple['platform'] = 'Apple TV'

Data_HBO = pd.read_csv('../data/raw/data_hbo_max.csv')
Data_HBO['platform'] = 'HBO Max'

Data_Netflix = pd.read_csv('../data/raw/data_netflix.csv')
Data_Netflix['platform'] = 'Netflix'

# %% [markdown]
# ## 1.1 Concatenación de la data - plataformas

# %%
toda_data = pd.concat([Data_Amazon, Data_Apple, Data_HBO, Data_Netflix], ignore_index=True)
toda_data
# Out:
#                    title   type                  genres  releaseYear  \
# 0                Blondie  movie          Comedy, Family       1938.0
# 1                  Ariel  movie  Comedy, Crime, Romance       1988.0
# 2             Four Rooms  movie                  Comedy       1995.0
# 3         Judgment Night  movie    Action, Crime, Drama       1993.0
# 4           Forrest Gump  movie          Drama, Romance       1994.0
# ...                  ...    ...                     ...          ...
# 117491               NaN     tv               Animation       2016.0
# 117492               NaN     tv               Animation       2005.0
# 117493  La Vida es Sueño     tv             Documentary       2024.0
# 117494               NaN     tv                     NaN       2021.0
# 117495               NaN     tv                     NaN       2022.0
#
#             imdbId  imdbAverageRating  imdbNumVotes  \
# 0        tt0029927                6.9         890.0
# 1        tt0094675                7.4        8829.0
# 2        tt0113101                6.7      112881.0
# 3        tt0107286                6.6       19385.0
# 4        tt0109830                8.8     2330534.0
# ...            ...                ...           ...
# 117491         NaN                NaN           NaN
# 117492         NaN                NaN           NaN
# 117493  tt32268206                NaN           NaN
# 117494         NaN                NaN           NaN
# 117495         NaN                NaN           NaN
#
#                                        availableCountries            platform
# 0                                                  US, ZA  Amazon Prime Video
# 1                                                      JP  Amazon Prime Video
# 2                                                  AT, DE  Amazon Prime Video
# 3                                                      US  Amazon Prime Video
# 4              AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN  Amazon Prime Video
# ...                                                   ...                 ...
# 117491  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...             Netflix
# 117492                                             JP, KR             Netflix
# 117493  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...             Netflix
# 117494                                                 US             Netflix
# 117495  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...             Netflix
#
# [117496 rows x 9 columns]

# %% [markdown]
# ## 2.0 Carga de data - Suscriptores

# %%
Suscriptores =pd.read_csv('../data/external/streaming_platforms_Suscriptores.csv')
Suscriptores
# Out:
#            Plataforma  Suscriptores (Millones)  \
# 0             Netflix                    261.0
# 1  Amazon Prime Video                    200.0
# 2             HBO Max                     79.9
# 3           Apple TV+                     40.0
#
#           Continentes Disponibles  \
# 0  América, Europa, Asia, Oceanía
# 1  América, Europa, Asia, Oceanía
# 2           América, Europa, Asia
# 3           América, Europa, Asia
#
#                     Porcentaje de Uso por Continente  \
# 0  América: 35%, Europa: 30%, Asia: 25%, Oceanía:...
# 1  América: 40%, Europa: 25%, Asia: 25%, Oceanía:...
# 2               América: 50%, Europa: 35%, Asia: 15%
# 3               América: 45%, Europa: 30%, Asia: 25%
#
#                              Suscriptores por Región
# 0  América del Norte: 74.3M, EMEA: 76.7M, América...
# 1  América: 80M, Europa: 50M, Asia: 50M, Oceanía:...
# 2      América: 39.95M, Europa: 27.97M, Asia: 11.99M
# 3               América: 18M, Europa: 12M, Asia: 10M

# %% [markdown]
# ## 3.0 Carga de Datos - Precios

# %%
precios =pd.read_csv('../data/external/streaming_platforms_prices.csv')
precios
# Out:
#            Plataforma Títulos Populares  Puntuación de Usuarios  \
# 0             Netflix   Engaños, Berlín                     8.5
# 1             Netflix   Engaños, Berlín                     8.5
# 2             Netflix   Engaños, Berlín                     8.5
# 3             Netflix   Engaños, Berlín                     8.5
# 4  Amazon Prime Video         Culpa mía                     8.0
# 5  Amazon Prime Video         Culpa mía                     8.0
# 6  Amazon Prime Video         Culpa mía                     8.0
# 7             HBO Max   No especificado                     8.2
# 8             HBO Max   No especificado                     8.2
# 9           Apple TV+   No especificado                     7.8
#
#   Planes de Suscripción  Reproducción simultánea Resolución Máxima  \
# 0              Estándar                        1           Full HD
# 1              Estándar                        2           Full HD
# 2               Premium                        4                4K
# 3                Básico                        1                HD
# 4              Estándar                        2                4K
# 5              Estándar                        2                4K
# 6               Student                        1                4K
# 7              Estándar                        2           Full HD
# 8               Premium                        4                4K
# 9              Estándar                        1            4K HDR
#
#    Días de Prueba gratuita Compartir cuenta Publicidad Fecha de lanzamiento  \
# 0                        0               No         Sí           20/10/2015
# 1                        0               Sí         No           20/10/2015
# 2                        0               Sí         No           20/10/2015
# 3                        0               No         No           20/10/2015
# 4                       30               Sí         Sí           14/12/2016
# 5                       30               Sí         No           14/12/2016
# 6                       90               No         Sí           14/12/2016
# 7                        0               Sí         No           26/10/2021
# 8                        0               Sí         No           26/10/2021
# 9                        7               Sí         No           01/11/2019
#
#    Precio Actual Títulos Populares Recientes  Puntuaciones de Usuarios  \
# 0           6.99             Engaños, Berlín                       8.5
# 1          13.99             Engaños, Berlín                       8.5
# 2          19.99             Engaños, Berlín                       8.5
# 3           7.99             Engaños, Berlín                       8.5
# 4           4.99                   Culpa mía                       8.0
# 5           6.98                   Culpa mía                       8.0
# 6           2.49                   Culpa mía                       8.0
# 7           9.99             No especificado                       8.2
# 8          13.99             No especificado                       8.2
# 9           6.99             No especificado                       7.8
#
#    Tiene Plan Anual
# 0             False
# 1             False
# 2             False
# 3             False
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
