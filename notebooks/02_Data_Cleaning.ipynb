# %% [markdown]
# # Limpieza de los Datos

# %% [markdown]
# ## Librerías

# %%
import numpy as np 
import pandas as pd
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga de Datos

# %%
Data_Amazon = pd.read_csv('../data/raw/data_amazon_prime_video.csv')
Data_Amazon['platform'] = 'Amazon Prime Video'

Data_Apple = pd.read_csv('../data/raw/data_apple_tv.csv')
Data_Apple['platform'] = 'Apple TV'

Data_HBO = pd.read_csv('../data/raw/data_hbo_max.csv')
Data_HBO['platform'] = 'HBO Max'

Data_Netflix = pd.read_csv('../data/raw/data_netflix.csv')
Data_Netflix['platform'] = 'Netflix'

all_data = pd.concat([Data_Amazon, Data_Apple, Data_HBO, Data_Netflix], ignore_index=True)

# %%
all_data
# Out:
#                    title   type                  genres  releaseYear  \
# 0                Blondie  movie          Comedy, Family       1938.0
# 1                  Ariel  movie  Comedy, Crime, Romance       1988.0
# 2             Four Rooms  movie                  Comedy       1995.0
# 3         Judgment Night  movie    Action, Crime, Drama       1993.0
# 4           Forrest Gump  movie          Drama, Romance       1994.0
# ...                  ...    ...                     ...          ...
# 117491               NaN     tv               Animation       2016.0
# 117492               NaN     tv               Animation       2005.0
# 117493  La Vida es Sueño     tv             Documentary       2024.0
# 117494               NaN     tv                     NaN       2021.0
# 117495               NaN     tv                     NaN       2022.0
#
#             imdbId  imdbAverageRating  imdbNumVotes  \
# 0        tt0029927                6.9         890.0
# 1        tt0094675                7.4        8829.0
# 2        tt0113101                6.7      112881.0
# 3        tt0107286                6.6       19385.0
# 4        tt0109830                8.8     2330534.0
# ...            ...                ...           ...
# 117491         NaN                NaN           NaN
# 117492         NaN                NaN           NaN
# 117493  tt32268206                NaN           NaN
# 117494         NaN                NaN           NaN
# 117495         NaN                NaN           NaN
#
#                                        availableCountries            platform
# 0                                                  US, ZA  Amazon Prime Video
# 1                                                      JP  Amazon Prime Video
# 2                                                  AT, DE  Amazon Prime Video
# 3                                                      US  Amazon Prime Video
# 4              AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN  Amazon Prime Video
# ...                                                   ...                 ...
# 117491  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...             Netflix
# 117492                                             JP, KR             Netflix
# 117493  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...             Netflix
# 117494                                                 US             Netflix
# 117495  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...             Netflix
#
# [117496 rows x 9 columns]

# %% [markdown]
# ## Limpieza de Datos

# %% [markdown]
# ### Eliminación de titulos faltantes

# %%
all_data.dropna(subset=['title'], inplace=True)

# %% [markdown]
# ### Eliminación de años futuros

# %%
all_data = all_data[all_data['releaseYear'] <= 2024]

# %% [markdown]
# ### Eliminación de generos no especificados

# %%
all_data = all_data.dropna(subset=['genres'])

# %% [markdown]
# ### Eliminación de datos duplicados

# %%
all_data.drop_duplicates(subset=['title', 'type', 'releaseYear', 'platform'], keep='first', inplace=True)

# %% [markdown]
# ### Imputación de valores

# %%
all_data['imdbAverageRating'] = all_data['imdbAverageRating'].fillna(all_data['imdbAverageRating'].median())
all_data['imdbNumVotes'] = all_data['imdbNumVotes'].fillna(all_data['imdbNumVotes'].median())

# %%
all_data
# Out:
#                                              title   type  \
# 0                                          Blondie  movie
# 1                                            Ariel  movie
# 2                                       Four Rooms  movie
# 3                                   Judgment Night  movie
# 4                                     Forrest Gump  movie
# ...                                            ...    ...
# 117476                                  S.E.R.E.G.     tv
# 117479                            The Later Daters     tv
# 117482  The Kings of Tupelo: A Southern Crime Saga     tv
# 117489           Das Boot - Die komplette TV-Serie     tv
# 117493                            La Vida es Sueño     tv
#
#                         genres  releaseYear      imdbId  imdbAverageRating  \
# 0               Comedy, Family       1938.0   tt0029927                6.9
# 1       Comedy, Crime, Romance       1988.0   tt0094675                7.4
# 2                       Comedy       1995.0   tt0113101                6.7
# 3         Action, Crime, Drama       1993.0   tt0107286                6.6
# 4               Drama, Romance       1994.0   tt0109830                8.8
# ...                        ...          ...         ...                ...
# 117476                  Action       2024.0  tt31242061                3.8
# 117479     Reality-TV, Romance       2024.0  tt34599590                7.0
# 117482      Crime, Documentary       2024.0  tt34682275                6.6
# 117489              Drama, War       1985.0  tt30970892                8.7
# 117493             Documentary       2024.0  tt32268206                6.3
#
#         imdbNumVotes                                 availableCountries  \
# 0              890.0                                             US, ZA
# 1             8829.0                                                 JP
# 2           112881.0                                             AT, DE
# 3            19385.0                                                 US
# 4          2330534.0         AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN
# ...              ...                                                ...
# 117476        4564.0                                                 HU
# 117479         268.0  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 117482         808.0  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 117489         157.0                                     AT, CH, DE, LI
# 117493         723.0  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...
#
#                   platform
# 0       Amazon Prime Video
# 1       Amazon Prime Video
# 2       Amazon Prime Video
# 3       Amazon Prime Video
# 4       Amazon Prime Video
# ...                    ...
# 117476             Netflix
# 117479             Netflix
# 117482             Netflix
# 117489             Netflix
# 117493             Netflix
#
# [111738 rows x 9 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111738 entries, 0 to 117493
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   title               111738 non-null  object
#  1   type                111738 non-null  object
#  2   genres              111738 non-null  object
#  3   releaseYear         111738 non-null  float64
#  4   imdbId              107143 non-null  object
#  5   imdbAverageRating   111738 non-null  float64
#  6   imdbNumVotes        111738 non-null  float64
#  7   availableCountries  111738 non-null  object
#  8   platform            111738 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 8.5+ MB

# %%
all_data.isnull().sum()
# Out:
# title                    0
# type                     0
# genres                   0
# releaseYear              0
# imdbId                4595
# imdbAverageRating        0
# imdbNumVotes             0
# availableCountries       0
# platform                 0
# dtype: int64

# %% [markdown]
# ## Guardamos la data limpia

# %%
all_data.to_csv('../data/processed/all_data_cleaned.csv', index=False)
