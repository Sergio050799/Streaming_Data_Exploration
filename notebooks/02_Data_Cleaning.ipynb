# %% [markdown]
# # Limpieza de los Datos

# %% [markdown]
# ## 0.1 Librerías

# %%
import numpy as np 
import pandas as pd
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.1 Carga de Datos - Plataformas

# %%
Data_Amazon = pd.read_csv('../data/raw/data_amazon_prime_video.csv')
Data_Amazon['platform'] = 'Amazon Prime Video'
Data_Amazon

Data_Apple = pd.read_csv('../data/raw/data_apple_tv.csv')
Data_Apple['platform'] = 'Apple TV'
Data_Apple

Data_HBO = pd.read_csv('../data/raw/data_hbo_max.csv')
Data_HBO['platform'] = 'HBO Max'
Data_HBO

Data_Netflix = pd.read_csv('../data/raw/data_netflix.csv')
Data_Netflix['platform'] = 'Netflix'
Data_Netflix

all_data = pd.concat([Data_Amazon, Data_Apple, Data_HBO, Data_Netflix], ignore_index=True)
all_data
# Out:
#                    title   type                  genres  releaseYear  \
# 0                Blondie  movie          Comedy, Family       1938.0
# 1                  Ariel  movie  Comedy, Crime, Romance       1988.0
# 2             Four Rooms  movie                  Comedy       1995.0
# 3         Judgment Night  movie    Action, Crime, Drama       1993.0
# 4           Forrest Gump  movie          Drama, Romance       1994.0
# ...                  ...    ...                     ...          ...
# 117491               NaN     tv               Animation       2016.0
# 117492               NaN     tv               Animation       2005.0
# 117493  La Vida es Sueño     tv             Documentary       2024.0
# 117494               NaN     tv                     NaN       2021.0
# 117495               NaN     tv                     NaN       2022.0
#
#             imdbId  imdbAverageRating  imdbNumVotes  \
# 0        tt0029927                6.9         890.0
# 1        tt0094675                7.4        8829.0
# 2        tt0113101                6.7      112881.0
# 3        tt0107286                6.6       19385.0
# 4        tt0109830                8.8     2330534.0
# ...            ...                ...           ...
# 117491         NaN                NaN           NaN
# 117492         NaN                NaN           NaN
# 117493  tt32268206                NaN           NaN
# 117494         NaN                NaN           NaN
# 117495         NaN                NaN           NaN
#
#                                        availableCountries            platform
# 0                                                  US, ZA  Amazon Prime Video
# 1                                                      JP  Amazon Prime Video
# 2                                                  AT, DE  Amazon Prime Video
# 3                                                      US  Amazon Prime Video
# 4              AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN  Amazon Prime Video
# ...                                                   ...                 ...
# 117491  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...             Netflix
# 117492                                             JP, KR             Netflix
# 117493  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...             Netflix
# 117494                                                 US             Netflix
# 117495  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...             Netflix
#
# [117496 rows x 9 columns]

# %% [markdown]
# ## 1.2 Carga de Datos - Precios

# %%
prices_data = pd.read_csv('../data/external/streaming_platforms_prices.csv')
prices_data
# Out:
#            Plataforma                Versión  Reproducción simultánea  \
# 0  Amazon Prime Video  Estándar con anuncios                        2
# 1  Amazon Prime Video  Estándar sin anuncios                        2
# 2  Amazon Prime Video   Student con anuncios                        1
# 3           Apple TV+               Estándar                        1
# 4             Netflix  Estándar con anuncios                        1
# 5             Netflix               Estándar                        2
# 6             Netflix                Premium                        4
# 7             Netflix                 Básico                        1
# 8                 Max               Estándar                        2
# 9                 Max                Premium                        4
#
#   Resolución Máxima Días de Prueba gratuita Compartir cuenta Publicidad  \
# 0                4K                      30               Sí         Sí
# 1                4K                      30               Sí         No
# 2                4K                      90               No         Sí
# 3            4K HDR                       7               Sí         No
# 4           Full HD                       -               No         Sí
# 5           Full HD                       -               Sí         No
# 6                4K                       -               Sí         No
# 7                HD                       -               No         No
# 8           Full HD                       -               Sí         No
# 9                4K                       -               Sí         No
#
#    Precio Inicial - Mensual Fecha de lanzamiento  Precio Actual - Mensual  \
# 0                      4.99           14/12/2016                     4.99
# 1                      4.99           14/12/2016                     6.98
# 2                      2.49           14/12/2016                     2.49
# 3                      4.99           01/11/2019                     6.99
# 4                      5.49           20/10/2015                     6.99
# 5                      9.99           20/10/2015                    13.99
# 6                     11.99           20/10/2015                    19.99
# 7                      7.99           20/10/2015                     7.99
# 8                      8.99           26/10/2021                     9.99
# 9                       NaN           26/10/2021                    13.99
#
#    Precio Inicial - Anual  Precio Actual - Anual
# 0                   19.95                  49.90
# 1                   19.95                    NaN
# 2                   19.95                  24.95
# 3                   49.99                  99.99
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# 6                     NaN                    NaN
# 7                     NaN                    NaN
# 8                   69.99                  99.90
# 9                     NaN                 139.99

# %% [markdown]
# ## 2.0 Limpieza de Datos - Plataformas

# %% [markdown]
# ### Eliminación de titulos faltantes

# %%
all_data.dropna(subset=['title'], inplace=True)

# %% [markdown]
# ### Eliminación de años futuros

# %%
all_data = all_data[all_data['releaseYear'] <= 2024]

# %% [markdown]
# ### Eliminación de generos no especificados

# %%
all_data = all_data.dropna(subset=['genres'])

# %% [markdown]
# ### Eliminación de datos duplicados

# %%
all_data.drop_duplicates(subset=['title', 'type', 'releaseYear', 'platform'], keep='first', inplace=True)

# %% [markdown]
# ### Imputación de valores

# %%
all_data['imdbAverageRating'] = all_data['imdbAverageRating'].fillna(all_data['imdbAverageRating'].median())
all_data['imdbNumVotes'] = all_data['imdbNumVotes'].fillna(all_data['imdbNumVotes'].median())

# %%
all_data
# Out:
#                                              title   type  \
# 0                                          Blondie  movie
# 1                                            Ariel  movie
# 2                                       Four Rooms  movie
# 3                                   Judgment Night  movie
# 4                                     Forrest Gump  movie
# ...                                            ...    ...
# 117476                                  S.E.R.E.G.     tv
# 117479                            The Later Daters     tv
# 117482  The Kings of Tupelo: A Southern Crime Saga     tv
# 117489           Das Boot - Die komplette TV-Serie     tv
# 117493                            La Vida es Sueño     tv
#
#                         genres  releaseYear      imdbId  imdbAverageRating  \
# 0               Comedy, Family       1938.0   tt0029927                6.9
# 1       Comedy, Crime, Romance       1988.0   tt0094675                7.4
# 2                       Comedy       1995.0   tt0113101                6.7
# 3         Action, Crime, Drama       1993.0   tt0107286                6.6
# 4               Drama, Romance       1994.0   tt0109830                8.8
# ...                        ...          ...         ...                ...
# 117476                  Action       2024.0  tt31242061                3.8
# 117479     Reality-TV, Romance       2024.0  tt34599590                7.0
# 117482      Crime, Documentary       2024.0  tt34682275                6.6
# 117489              Drama, War       1985.0  tt30970892                8.7
# 117493             Documentary       2024.0  tt32268206                6.3
#
#         imdbNumVotes                                 availableCountries  \
# 0              890.0                                             US, ZA
# 1             8829.0                                                 JP
# 2           112881.0                                             AT, DE
# 3            19385.0                                                 US
# 4          2330534.0         AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN
# ...              ...                                                ...
# 117476        4564.0                                                 HU
# 117479         268.0  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 117482         808.0  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 117489         157.0                                     AT, CH, DE, LI
# 117493         723.0  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...
#
#                   platform
# 0       Amazon Prime Video
# 1       Amazon Prime Video
# 2       Amazon Prime Video
# 3       Amazon Prime Video
# 4       Amazon Prime Video
# ...                    ...
# 117476             Netflix
# 117479             Netflix
# 117482             Netflix
# 117489             Netflix
# 117493             Netflix
#
# [111738 rows x 9 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111738 entries, 0 to 117493
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   title               111738 non-null  object
#  1   type                111738 non-null  object
#  2   genres              111738 non-null  object
#  3   releaseYear         111738 non-null  float64
#  4   imdbId              107143 non-null  object
#  5   imdbAverageRating   111738 non-null  float64
#  6   imdbNumVotes        111738 non-null  float64
#  7   availableCountries  111738 non-null  object
#  8   platform            111738 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 8.5+ MB

# %%
all_data.isnull().sum()
# Out:
# title                    0
# type                     0
# genres                   0
# releaseYear              0
# imdbId                4595
# imdbAverageRating        0
# imdbNumVotes             0
# availableCountries       0
# platform                 0
# dtype: int64

# %% [markdown]
# ## 2.1 Limpieza de Datos - Precios

# %% [markdown]
# ### Conversión de las colummas a formatos adecuado

# %%
prices_data['Días de Prueba gratuita'] = prices_data['Días de Prueba gratuita'].replace('-', 0).astype(int)
prices_data['Precio Actual - Mensual'] = prices_data['Precio Actual - Mensual'].fillna(prices_data['Precio Inicial - Mensual']) 
prices_data['Precio Actual - Mensual'] = prices_data['Precio Actual - Mensual'].astype(float) 

prices_data
# Out:
#            Plataforma                Versión  Reproducción simultánea  \
# 0  Amazon Prime Video  Estándar con anuncios                        2
# 1  Amazon Prime Video  Estándar sin anuncios                        2
# 2  Amazon Prime Video   Student con anuncios                        1
# 3           Apple TV+               Estándar                        1
# 4             Netflix  Estándar con anuncios                        1
# 5             Netflix               Estándar                        2
# 6             Netflix                Premium                        4
# 7             Netflix                 Básico                        1
# 8                 Max               Estándar                        2
# 9                 Max                Premium                        4
#
#   Resolución Máxima  Días de Prueba gratuita Compartir cuenta Publicidad  \
# 0                4K                       30               Sí         Sí
# 1                4K                       30               Sí         No
# 2                4K                       90               No         Sí
# 3            4K HDR                        7               Sí         No
# 4           Full HD                        0               No         Sí
# 5           Full HD                        0               Sí         No
# 6                4K                        0               Sí         No
# 7                HD                        0               No         No
# 8           Full HD                        0               Sí         No
# 9                4K                        0               Sí         No
#
#    Precio Inicial - Mensual Fecha de lanzamiento  Precio Actual - Mensual  \
# 0                      4.99           14/12/2016                     4.99
# 1                      4.99           14/12/2016                     6.98
# 2                      2.49           14/12/2016                     2.49
# 3                      4.99           01/11/2019                     6.99
# 4                      5.49           20/10/2015                     6.99
# 5                      9.99           20/10/2015                    13.99
# 6                     11.99           20/10/2015                    19.99
# 7                      7.99           20/10/2015                     7.99
# 8                      8.99           26/10/2021                     9.99
# 9                       NaN           26/10/2021                    13.99
#
#    Precio Inicial - Anual  Precio Actual - Anual
# 0                   19.95                  49.90
# 1                   19.95                    NaN
# 2                   19.95                  24.95
# 3                   49.99                  99.99
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# 6                     NaN                    NaN
# 7                     NaN                    NaN
# 8                   69.99                  99.90
# 9                     NaN                 139.99

# %%
prices_data.drop_duplicates(inplace=True)
prices_data
# Out:
#            Plataforma                Versión  Reproducción simultánea  \
# 0  Amazon Prime Video  Estándar con anuncios                        2
# 1  Amazon Prime Video  Estándar sin anuncios                        2
# 2  Amazon Prime Video   Student con anuncios                        1
# 3           Apple TV+               Estándar                        1
# 4             Netflix  Estándar con anuncios                        1
# 5             Netflix               Estándar                        2
# 6             Netflix                Premium                        4
# 7             Netflix                 Básico                        1
# 8                 Max               Estándar                        2
# 9                 Max                Premium                        4
#
#   Resolución Máxima  Días de Prueba gratuita Compartir cuenta Publicidad  \
# 0                4K                       30               Sí         Sí
# 1                4K                       30               Sí         No
# 2                4K                       90               No         Sí
# 3            4K HDR                        7               Sí         No
# 4           Full HD                        0               No         Sí
# 5           Full HD                        0               Sí         No
# 6                4K                        0               Sí         No
# 7                HD                        0               No         No
# 8           Full HD                        0               Sí         No
# 9                4K                        0               Sí         No
#
#    Precio Inicial - Mensual Fecha de lanzamiento  Precio Actual - Mensual  \
# 0                      4.99           14/12/2016                     4.99
# 1                      4.99           14/12/2016                     6.98
# 2                      2.49           14/12/2016                     2.49
# 3                      4.99           01/11/2019                     6.99
# 4                      5.49           20/10/2015                     6.99
# 5                      9.99           20/10/2015                    13.99
# 6                     11.99           20/10/2015                    19.99
# 7                      7.99           20/10/2015                     7.99
# 8                      8.99           26/10/2021                     9.99
# 9                       NaN           26/10/2021                    13.99
#
#    Precio Inicial - Anual  Precio Actual - Anual
# 0                   19.95                  49.90
# 1                   19.95                    NaN
# 2                   19.95                  24.95
# 3                   49.99                  99.99
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# 6                     NaN                    NaN
# 7                     NaN                    NaN
# 8                   69.99                  99.90
# 9                     NaN                 139.99

# %%
prices_data.describe(include='all')
# Out:
#        Plataforma   Versión  Reproducción simultánea Resolución Máxima  \
# count          10        10                10.000000                10
# unique          4         6                      NaN                 4
# top       Netflix  Estándar                      NaN                4K
# freq            4         3                      NaN                 5
# mean          NaN       NaN                 2.000000               NaN
# std           NaN       NaN                 1.154701               NaN
# min           NaN       NaN                 1.000000               NaN
# 25%           NaN       NaN                 1.000000               NaN
# 50%           NaN       NaN                 2.000000               NaN
# 75%           NaN       NaN                 2.000000               NaN
# max           NaN       NaN                 4.000000               NaN
#
#         Días de Prueba gratuita Compartir cuenta Publicidad  \
# count                 10.000000               10         10
# unique                      NaN                2          2
# top                         NaN               Sí         No
# freq                        NaN                7          7
# mean                  15.700000              NaN        NaN
# std                   28.836898              NaN        NaN
# min                    0.000000              NaN        NaN
# 25%                    0.000000              NaN        NaN
# 50%                    0.000000              NaN        NaN
# 75%                   24.250000              NaN        NaN
# max                   90.000000              NaN        NaN
#
#         Precio Inicial - Mensual Fecha de lanzamiento  \
# count                   9.000000                   10
# unique                       NaN                    4
# top                          NaN           20/10/2015
# freq                         NaN                    4
# mean                    6.878889                  NaN
# std                     3.028797                  NaN
# min                     2.490000                  NaN
# 25%                     4.990000                  NaN
# 50%                     5.490000                  NaN
# 75%                     8.990000                  NaN
# max                    11.990000                  NaN
#
#         Precio Actual - Mensual  Precio Inicial - Anual  Precio Actual - Anual
# count                 10.000000                 5.00000               5.000000
# unique                      NaN                     NaN                    NaN
# top                         NaN                     NaN                    NaN
# freq                        NaN                     NaN                    NaN
# mean                   9.439000                35.96600              82.946000
# std                    5.177667                23.04258              45.517931
# min                    2.490000                19.95000              24.950000
# 25%                    6.982500                19.95000              49.900000
# 50%                    7.490000                19.95000              99.900000
# 75%                   12.990000                49.99000              99.990000
# max                   19.990000                69.99000             139.990000

# %% [markdown]
# ## 3.0 Guardamos la data limpia

# %%
all_data.to_csv('../data/processed/all_data_cleaned.csv', index=False)

# %%
prices_data.to_csv('../data/processed/streaming_platforms_prices_cleaned.csv', index=False)
